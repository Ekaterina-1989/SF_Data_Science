# %% [markdown]
# ### <center> **Домашнее задание: EDA-5. Проектирование экспериментов.**

# %% [markdown]
# ### *Импорт библиотек*

# %%
# Загружаем необходимые библиотеки
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### *Настройка CometML*

# %% [markdown]
# <img src="images/Comet__ML.jpg">

# %%
# !pip install comet_ml

# %%
from comet_ml import Experiment

# %%
# Создадим эксперимент с помощью API ключа
experiment = Experiment(
    api_key='ntcQzScTapFs832nzXG6PFaav',
    project_name='medical-appointment',
    workspace='g-catharina-g',
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/g-catharina-g/medical-appointment/a81cdd72d8684f8d8428b3ee5c51ca75

# %% [markdown]
# ### *Загрузка данных*

# %%
# Загружаем датасет
df = pd.read_csv('data/KaggleV2-May-2016.csv')

# %%
# Выведем первые пять строк таблицы с помощью head()
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
# Выделим 7 числовых признаков
numeric_data = df[["Age", "Scholarship", "Hipertension", "Diabetes", "Alcoholism", "Handcap", "SMS_received"]]
# Выведем первые пять строк таблицы с помощью head()
numeric_data.head()
# Out:
#    Age  Scholarship  Hipertension  Diabetes  Alcoholism  Handcap  SMS_received
# 0   62            0             1         0           0        0             0
# 1   56            0             0         0           0        0             0
# 2   62            0             0         0           0        0             0
# 3    8            0             0         0           0        0             0
# 4   56            0             1         1           0        0             0

# %% [markdown]
# ### *Визуализация*

# %%
# Построим тепловую карту корреляций числовых признаков
plt.figure(figsize=(10, 8))
ax = sns.heatmap(numeric_data.corr(numeric_only=True), annot=True, cmap="coolwarm")
ax.set_title("Тепловая карта корреляций числовых признаков")
# Логируем тепловую карту
experiment.log_figure(figure=plt)
plt.show()

# %%
# Завершаем эксперимент
experiment.end()
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : spatial_flyingfish_4175
# COMET INFO:     url                   : https://www.comet.com/g-catharina-g/medical-appointment/a81cdd72d8684f8d8428b3ee5c51ca75
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     figures                      : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (7.72 MB)
# ...
